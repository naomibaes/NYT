# %% [markdown]
# Author: Authors: Salvatore Giorgi, Daniel Roy Sadek Habib, Douglas Bellew, Garrick Sherman, and Brenda Curtis (modified and commented by Naomi Baes)
#
# Source: https://osf.io/uya29/
#
# Aim: This script is designed to download article metadata from the New York Times Archive API, extract article URLs for a specified range of years and save the URLs into text files organized by year.
# - It provides error handling for rate limiting (HTTP status code 429) and checks for the presence of required environment variables and file paths. It saves URLs after processing them for each year (in case the script is interrupted etc.)
# - The script also checks if the output directory exists and creted it if it does not. If the directory already exists, it will simply use that directory
#
# Note: To run this script successfully, you need to get your API key from the NYT Developer site and save it in a file called "nyt_api_key.txt"

# %%
# Setup logging configuration
import logging
import time
import os
import requests

logger = logging.getLogger('NYT downloader')
logging.basicConfig(level=logging.INFO)

# Constants
API_KEY_FILE_PATH = 'nyt_api_key.txt'
BASE_URL = 'https://api.nytimes.com/svc/archive/v1/{year}/{month}.json?api-key={key}'

# Function to read API key from file
def read_api_key_from_file(file_path):
    try:
        with open(file_path, 'r') as file:
            api_key = file.read().strip()
        return api_key
    except FileNotFoundError:
        logger.error(f"API key file '{file_path}' not found.")
        raise
    except Exception as e:
        logger.error(f"Error reading API key file: {e}")
        raise

# Read the API key from the file
try:
    NYT_KEY = read_api_key_from_file(API_KEY_FILE_PATH)
except Exception:
    logger.error("Unable to retrieve API key. Exiting.")
    exit(1)

# Set the API key as an environment variable
os.environ['NYT_KEY'] = NYT_KEY

# fetch_from_api Function: This function constructs the URL for making requests to the New York Times Archive API 
# based on the specified year, month, and API key. It then sends a GET request to the API and handles the case where 
# the API responds with HTTP status code 429 (indicating too many requests) by waiting for 60 seconds before retrying the request.
def fetch_from_api(year, month, key, retry_count=0):
    url = BASE_URL.format(year=year, month=month, key=key)
    logger.info('Fetching {}'.format(url))
    try:
        res = requests.get(url)
        res.raise_for_status()  # Raise an exception for any HTTP error status
        return res.json()
    except requests.HTTPError as e:
        if e.response.status_code == 429:
            if retry_count < MAX_RETRY:
                # Exponential backoff: Wait for an exponentially increasing amount of time before retrying.
                delay = (2 ** retry_count) * RETRY_DELAY
                logger.error('Got HTTP 429: Too many requests. Retrying in {} seconds.'.format(delay))
                time.sleep(delay)
                return fetch_from_api(year, month, key, retry_count + 1)
            else:
                logger.error('Max retry limit reached. Unable to fetch data.')
                raise
        else:
            logger.error('HTTP Error: {}'.format(e))
            raise

# extract_urls Function: This function takes the JSON response from the New York Times API and extracts the web URLs of 
# the articles from it.
def extract_urls(api_results):
    urls = []
    for doc in api_results['response']['docs']:
        url = doc['web_url']
        urls.append(url)
    logger.info('Extracted {} urls'.format(len(urls)))
    return urls

# Save urls to file
def save_urls(urls, save_location, year):
    url_file = os.path.join(save_location, f'urls_{year}.txt')
    logger.info('Saving urls to {}'.format(url_file))
    with open(url_file, 'w') as out:
        for url in urls:
            print(url, file=out)

# main Function: This function is the entry point of the script. It takes parameters for the start and end years, as well as 
# an optional parameter for the save location of the output file. Inside the function, it checks if the environment variable 
# containing the New York Times API key is set. If not, it prints a message prompting the user to set the API key and exits. 
# It also checks if the specified save location already exists, printing a message and exiting if it does.
# Inside the main function's loop over the range of years and months, it calls fetch_from_api to get article metadata for each 
# month and then calls extract_urls to extract the URLs from the metadata. The URLs are then appended to a list.
# After fetching all the URLs for a year, the script saves them to a file named 'urls_{year}.txt' in the specified save location.
def main(start_year, end_year, save_location='nyt'):
    key = os.environ.get('NYT_KEY')
    if key is None:
        logger.error('Please set the "{}" environment variable before running.'.format(NYT_KEY))
        return
    
    if not os.path.exists(save_location):
       os.mkdir(save_location)

    logger.info('Downloading article metadata for {}-{}'.format(start_year, end_year))
    urls = []
    for year in range(start_year, end_year + 1):
        for month in range(1, 13):
            if year != start_year or month != 1:
                time.sleep(6)
            try:
                article_metadata = fetch_from_api(year, month, key)
                url_chunk = extract_urls(article_metadata)
                urls += url_chunk
            except Exception as e:
                logger.error('Error processing data for {}/{}: {}'.format(year, month, e))
                continue
        
        # Save urls after processing each year
        save_urls(urls, save_location, year)
        urls = []  # Clear the urls list for the next year

# Define arguments
start_year = 2011
end_year = 2023 # then go until 2023
RETRY_DELAY = 60
MAX_RETRY = 10  # Define the maximum number of retry attempts
save_location = "C:/Users/naomi/OneDrive/COMP80004_PhDResearch/RESEARCH/DATA/CORPORA/MEDIA/NYT/output"

# Call main function
main(start_year, end_year, save_location)
# Out:
# INFO:NYT downloader:Downloading article metadata for 2011-2023
# INFO:NYT downloader:Fetching https://api.nytimes.com/svc/archive/v1/2011/1.json?api-key=yHXr5g15kLco2gm87B9GKpQ1USXUQZPO
# INFO:NYT downloader:Extracted 8478 urls
# INFO:NYT downloader:Fetching https://api.nytimes.com/svc/archive/v1/2011/2.json?api-key=yHXr5g15kLco2gm87B9GKpQ1USXUQZPO
# INFO:NYT downloader:Extracted 7917 urls
# INFO:NYT downloader:Fetching https://api.nytimes.com/svc/archive/v1/2011/3.json?api-key=yHXr5g15kLco2gm87B9GKpQ1USXUQZPO
# INFO:NYT downloader:Extracted 9026 urls
# INFO:NYT downloader:Fetching https://api.nytimes.com/svc/archive/v1/2011/4.json?api-key=yHXr5g15kLco2gm87B9GKpQ1USXUQZPO
# INFO:NYT downloader:Extracted 8751 urls
# INFO:NYT downloader:Fetching https://api.nytimes.com/svc/archive/v1/2011/5.json?api-key=yHXr5g15kLco2gm87B9GKpQ1USXUQZPO
# INFO:NYT downloader:Extracted 8732 urls
# INFO:NYT downloader:Fetching https://api.nytimes.com/svc/archive/v1/2011/6.json?api-key=yHXr5g15kLco2gm87B9GKpQ1USXUQZPO
# INFO:NYT downloader:Extracted 8602 urls
# INFO:NYT downloader:Fetching https://api.nytimes.com/svc/archive/v1/2011/7.json?api-key=yHXr5g15kLco2gm87B9GKpQ1USXUQZPO
# INFO:NYT downloader:Extracted 7987 urls
# INFO:NYT downloader:Fetching https://api.nytimes.com/svc/archive/v1/2011/8.json?api-key=yHXr5g15kLco2gm87B9GKpQ1USXUQZPO
# INFO:NYT downloader:Extracted 8138 urls
# INFO:NYT downloader:Fetching https://api.nytimes.com/svc/archive/v1/2011/9.json?api-key=yHXr5g15kLco2gm87B9GKpQ1USXUQZPO
# INFO:NYT downloader:Extracted 9200 urls
# INFO:NYT downloader:Fetching https://api.nytimes.com/svc/archive/v1/2011/10.json?api-key=yHXr5g15kLco2gm87B9GKpQ1USXUQZPO
# INFO:NYT downloader:Extracted 8912 urls
# INFO:NYT downloader:Fetching https://api.nytimes.com/svc/archive/v1/2011/11.json?api-key=yHXr5g15kLco2gm87B9GKpQ1USXUQZPO
# INFO:NYT downloader:Extracted 8722 urls
# INFO:NYT downloader:Fetching https://api.nytimes.com/svc/archive/v1/2011/12.json?api-key=yHXr5g15kLco2gm87B9GKpQ1USXUQZPO
# INFO:NYT downloader:Extracted 8504 urls
# INFO:NYT downloader:Saving urls to C:/Users/naomi/OneDrive/COMP80004_PhDResearch/RESEARCH/DATA/CORPORA/MEDIA/NYT/output\urls_2011.txt
# INFO:NYT downloader:Fetching https://api.nytimes.com/svc/archive/v1/2012/1.json?api-key=yHXr5g15kLco2gm87B9GKpQ1USXUQZPO
# INFO:NYT downloader:Extracted 9168 urls
# INFO:NYT downloader:Fetching https://api.nytimes.com/svc/archive/v1/2012/2.json?api-key=yHXr5g15kLco2gm87B9GKpQ1USXUQZPO
# INFO:NYT downloader:Extracted 8796 urls
# INFO:NYT downloader:Fetching https://api.nytimes.com/svc/archive/v1/2012/3.json?api-key=yHXr5g15kLco2gm87B9GKpQ1USXUQZPO
# INFO:NYT downloader:Extracted 9280 urls
# INFO:NYT downloader:Fetching https://api.nytimes.com/svc/archive/v1/2012/4.json?api-key=yHXr5g15kLco2gm87B9GKpQ1USXUQZPO
# INFO:NYT downloader:Extracted 8240 urls
# INFO:NYT downloader:Fetching https://api.nytimes.com/svc/archive/v1/2012/5.json?api-key=yHXr5g15kLco2gm87B9GKpQ1USXUQZPO
# INFO:NYT downloader:Extracted 8862 urls
# INFO:NYT downloader:Fetching https://api.nytimes.com/svc/archive/v1/2012/6.json?api-key=yHXr5g15kLco2gm87B9GKpQ1USXUQZPO
# INFO:NYT downloader:Extracted 8704 urls
# INFO:NYT downloader:Fetching https://api.nytimes.com/svc/archive/v1/2012/7.json?api-key=yHXr5g15kLco2gm87B9GKpQ1USXUQZPO
# INFO:NYT downloader:Extracted 7795 urls
# INFO:NYT downloader:Fetching https://api.nytimes.com/svc/archive/v1/2012/8.json?api-key=yHXr5g15kLco2gm87B9GKpQ1USXUQZPO
# INFO:NYT downloader:Extracted 8202 urls
# INFO:NYT downloader:Fetching https://api.nytimes.com/svc/archive/v1/2012/9.json?api-key=yHXr5g15kLco2gm87B9GKpQ1USXUQZPO
# INFO:NYT downloader:Extracted 8306 urls
# INFO:NYT downloader:Fetching https://api.nytimes.com/svc/archive/v1/2012/10.json?api-key=yHXr5g15kLco2gm87B9GKpQ1USXUQZPO
# INFO:NYT downloader:Extracted 8731 urls
# INFO:NYT downloader:Fetching https://api.nytimes.com/svc/archive/v1/2012/11.json?api-key=yHXr5g15kLco2gm87B9GKpQ1USXUQZPO
# INFO:NYT downloader:Extracted 7959 urls
# INFO:NYT downloader:Fetching https://api.nytimes.com/svc/archive/v1/2012/12.json?api-key=yHXr5g15kLco2gm87B9GKpQ1USXUQZPO
# INFO:NYT downloader:Extracted 7212 urls
# INFO:NYT downloader:Saving urls to C:/Users/naomi/OneDrive/COMP80004_PhDResearch/RESEARCH/DATA/CORPORA/MEDIA/NYT/output\urls_2012.txt
# INFO:NYT downloader:Fetching https://api.nytimes.com/svc/archive/v1/2013/1.json?api-key=yHXr5g15kLco2gm87B9GKpQ1USXUQZPO
# INFO:NYT downloader:Extracted 7961 urls
# INFO:NYT downloader:Fetching https://api.nytimes.com/svc/archive/v1/2013/2.json?api-key=yHXr5g15kLco2gm87B9GKpQ1USXUQZPO
# INFO:NYT downloader:Extracted 7504 urls
# INFO:NYT downloader:Fetching https://api.nytimes.com/svc/archive/v1/2013/3.json?api-key=yHXr5g15kLco2gm87B9GKpQ1USXUQZPO
# INFO:NYT downloader:Extracted 8181 urls
# INFO:NYT downloader:Fetching https://api.nytimes.com/svc/archive/v1/2013/4.json?api-key=yHXr5g15kLco2gm87B9GKpQ1USXUQZPO
# INFO:NYT downloader:Extracted 7616 urls
# INFO:NYT downloader:Fetching https://api.nytimes.com/svc/archive/v1/2013/5.json?api-key=yHXr5g15kLco2gm87B9GKpQ1USXUQZPO
# INFO:NYT downloader:Extracted 7968 urls
# INFO:NYT downloader:Fetching https://api.nytimes.com/svc/archive/v1/2013/6.json?api-key=yHXr5g15kLco2gm87B9GKpQ1USXUQZPO
# INFO:NYT downloader:Extracted 7401 urls
# INFO:NYT downloader:Fetching https://api.nytimes.com/svc/archive/v1/2013/7.json?api-key=yHXr5g15kLco2gm87B9GKpQ1USXUQZPO
# INFO:NYT downloader:Extracted 6870 urls
# INFO:NYT downloader:Fetching https://api.nytimes.com/svc/archive/v1/2013/8.json?api-key=yHXr5g15kLco2gm87B9GKpQ1USXUQZPO
# INFO:NYT downloader:Extracted 6634 urls
# INFO:NYT downloader:Fetching https://api.nytimes.com/svc/archive/v1/2013/9.json?api-key=yHXr5g15kLco2gm87B9GKpQ1USXUQZPO
# INFO:NYT downloader:Extracted 7348 urls
# INFO:NYT downloader:Fetching https://api.nytimes.com/svc/archive/v1/2013/10.json?api-key=yHXr5g15kLco2gm87B9GKpQ1USXUQZPO
# INFO:NYT downloader:Extracted 7711 urls
# INFO:NYT downloader:Fetching https://api.nytimes.com/svc/archive/v1/2013/11.json?api-key=yHXr5g15kLco2gm87B9GKpQ1USXUQZPO
# INFO:NYT downloader:Extracted 7015 urls
# INFO:NYT downloader:Fetching https://api.nytimes.com/svc/archive/v1/2013/12.json?api-key=yHXr5g15kLco2gm87B9GKpQ1USXUQZPO
# INFO:NYT downloader:Extracted 6775 urls
# INFO:NYT downloader:Saving urls to C:/Users/naomi/OneDrive/COMP80004_PhDResearch/RESEARCH/DATA/CORPORA/MEDIA/NYT/output\urls_2013.txt
# INFO:NYT downloader:Fetching https://api.nytimes.com/svc/archive/v1/2014/1.json?api-key=yHXr5g15kLco2gm87B9GKpQ1USXUQZPO
# INFO:NYT downloader:Extracted 7337 urls
# INFO:NYT downloader:Fetching https://api.nytimes.com/svc/archive/v1/2014/2.json?api-key=yHXr5g15kLco2gm87B9GKpQ1USXUQZPO
# INFO:NYT downloader:Extracted 6941 urls
# INFO:NYT downloader:Fetching https://api.nytimes.com/svc/archive/v1/2014/3.json?api-key=yHXr5g15kLco2gm87B9GKpQ1USXUQZPO
# INFO:NYT downloader:Extracted 7187 urls
# INFO:NYT downloader:Fetching https://api.nytimes.com/svc/archive/v1/2014/4.json?api-key=yHXr5g15kLco2gm87B9GKpQ1USXUQZPO
# INFO:NYT downloader:Extracted 7344 urls
# INFO:NYT downloader:Fetching https://api.nytimes.com/svc/archive/v1/2014/5.json?api-key=yHXr5g15kLco2gm87B9GKpQ1USXUQZPO
# INFO:NYT downloader:Extracted 7549 urls
# INFO:NYT downloader:Fetching https://api.nytimes.com/svc/archive/v1/2014/6.json?api-key=yHXr5g15kLco2gm87B9GKpQ1USXUQZPO
# INFO:NYT downloader:Extracted 7345 urls
# INFO:NYT downloader:Fetching https://api.nytimes.com/svc/archive/v1/2014/7.json?api-key=yHXr5g15kLco2gm87B9GKpQ1USXUQZPO
# INFO:NYT downloader:Extracted 6814 urls
# INFO:NYT downloader:Fetching https://api.nytimes.com/svc/archive/v1/2014/8.json?api-key=yHXr5g15kLco2gm87B9GKpQ1USXUQZPO
# INFO:NYT downloader:Extracted 6577 urls
# INFO:NYT downloader:Fetching https://api.nytimes.com/svc/archive/v1/2014/9.json?api-key=yHXr5g15kLco2gm87B9GKpQ1USXUQZPO
# INFO:NYT downloader:Extracted 7585 urls
# INFO:NYT downloader:Fetching https://api.nytimes.com/svc/archive/v1/2014/10.json?api-key=yHXr5g15kLco2gm87B9GKpQ1USXUQZPO
# INFO:NYT downloader:Extracted 7862 urls
# INFO:NYT downloader:Fetching https://api.nytimes.com/svc/archive/v1/2014/11.json?api-key=yHXr5g15kLco2gm87B9GKpQ1USXUQZPO
# INFO:NYT downloader:Extracted 6709 urls
# INFO:NYT downloader:Fetching https://api.nytimes.com/svc/archive/v1/2014/12.json?api-key=yHXr5g15kLco2gm87B9GKpQ1USXUQZPO
# INFO:NYT downloader:Extracted 6701 urls
# INFO:NYT downloader:Saving urls to C:/Users/naomi/OneDrive/COMP80004_PhDResearch/RESEARCH/DATA/CORPORA/MEDIA/NYT/output\urls_2014.txt
# INFO:NYT downloader:Fetching https://api.nytimes.com/svc/archive/v1/2015/1.json?api-key=yHXr5g15kLco2gm87B9GKpQ1USXUQZPO
# INFO:NYT downloader:Extracted 6906 urls
# INFO:NYT downloader:Fetching https://api.nytimes.com/svc/archive/v1/2015/2.json?api-key=yHXr5g15kLco2gm87B9GKpQ1USXUQZPO
# INFO:NYT downloader:Extracted 6437 urls
# INFO:NYT downloader:Fetching https://api.nytimes.com/svc/archive/v1/2015/3.json?api-key=yHXr5g15kLco2gm87B9GKpQ1USXUQZPO
# INFO:NYT downloader:Extracted 6975 urls
# INFO:NYT downloader:Fetching https://api.nytimes.com/svc/archive/v1/2015/4.json?api-key=yHXr5g15kLco2gm87B9GKpQ1USXUQZPO
# INFO:NYT downloader:Extracted 6542 urls
# INFO:NYT downloader:Fetching https://api.nytimes.com/svc/archive/v1/2015/5.json?api-key=yHXr5g15kLco2gm87B9GKpQ1USXUQZPO
# INFO:NYT downloader:Extracted 6634 urls
# INFO:NYT downloader:Fetching https://api.nytimes.com/svc/archive/v1/2015/6.json?api-key=yHXr5g15kLco2gm87B9GKpQ1USXUQZPO
# INFO:NYT downloader:Extracted 6947 urls
# INFO:NYT downloader:Fetching https://api.nytimes.com/svc/archive/v1/2015/7.json?api-key=yHXr5g15kLco2gm87B9GKpQ1USXUQZPO
# INFO:NYT downloader:Extracted 6758 urls
# INFO:NYT downloader:Fetching https://api.nytimes.com/svc/archive/v1/2015/8.json?api-key=yHXr5g15kLco2gm87B9GKpQ1USXUQZPO
# INFO:NYT downloader:Extracted 6086 urls
# INFO:NYT downloader:Fetching https://api.nytimes.com/svc/archive/v1/2015/9.json?api-key=yHXr5g15kLco2gm87B9GKpQ1USXUQZPO
# INFO:NYT downloader:Extracted 6990 urls
# INFO:NYT downloader:Fetching https://api.nytimes.com/svc/archive/v1/2015/10.json?api-key=yHXr5g15kLco2gm87B9GKpQ1USXUQZPO
# INFO:NYT downloader:Extracted 7365 urls
# INFO:NYT downloader:Fetching https://api.nytimes.com/svc/archive/v1/2015/11.json?api-key=yHXr5g15kLco2gm87B9GKpQ1USXUQZPO
# INFO:NYT downloader:Extracted 6241 urls
# INFO:NYT downloader:Fetching https://api.nytimes.com/svc/archive/v1/2015/12.json?api-key=yHXr5g15kLco2gm87B9GKpQ1USXUQZPO
# INFO:NYT downloader:Extracted 6371 urls
# INFO:NYT downloader:Saving urls to C:/Users/naomi/OneDrive/COMP80004_PhDResearch/RESEARCH/DATA/CORPORA/MEDIA/NYT/output\urls_2015.txt
# INFO:NYT downloader:Fetching https://api.nytimes.com/svc/archive/v1/2016/1.json?api-key=yHXr5g15kLco2gm87B9GKpQ1USXUQZPO
# INFO:NYT downloader:Extracted 6265 urls
# INFO:NYT downloader:Fetching https://api.nytimes.com/svc/archive/v1/2016/2.json?api-key=yHXr5g15kLco2gm87B9GKpQ1USXUQZPO
# INFO:NYT downloader:Extracted 6448 urls
# INFO:NYT downloader:Fetching https://api.nytimes.com/svc/archive/v1/2016/3.json?api-key=yHXr5g15kLco2gm87B9GKpQ1USXUQZPO
# INFO:NYT downloader:Extracted 6487 urls
# INFO:NYT downloader:Fetching https://api.nytimes.com/svc/archive/v1/2016/4.json?api-key=yHXr5g15kLco2gm87B9GKpQ1USXUQZPO
# INFO:NYT downloader:Extracted 5927 urls
# INFO:NYT downloader:Fetching https://api.nytimes.com/svc/archive/v1/2016/5.json?api-key=yHXr5g15kLco2gm87B9GKpQ1USXUQZPO
# INFO:NYT downloader:Extracted 5921 urls
# INFO:NYT downloader:Fetching https://api.nytimes.com/svc/archive/v1/2016/6.json?api-key=yHXr5g15kLco2gm87B9GKpQ1USXUQZPO
# INFO:NYT downloader:Extracted 5920 urls
# INFO:NYT downloader:Fetching https://api.nytimes.com/svc/archive/v1/2016/7.json?api-key=yHXr5g15kLco2gm87B9GKpQ1USXUQZPO
# INFO:NYT downloader:Extracted 5594 urls
# INFO:NYT downloader:Fetching https://api.nytimes.com/svc/archive/v1/2016/8.json?api-key=yHXr5g15kLco2gm87B9GKpQ1USXUQZPO
# INFO:NYT downloader:Extracted 5224 urls
# INFO:NYT downloader:Fetching https://api.nytimes.com/svc/archive/v1/2016/9.json?api-key=yHXr5g15kLco2gm87B9GKpQ1USXUQZPO
# INFO:NYT downloader:Extracted 5894 urls
# INFO:NYT downloader:Fetching https://api.nytimes.com/svc/archive/v1/2016/10.json?api-key=yHXr5g15kLco2gm87B9GKpQ1USXUQZPO
# INFO:NYT downloader:Extracted 5511 urls
# INFO:NYT downloader:Fetching https://api.nytimes.com/svc/archive/v1/2016/11.json?api-key=yHXr5g15kLco2gm87B9GKpQ1USXUQZPO
# INFO:NYT downloader:Extracted 5331 urls
# INFO:NYT downloader:Fetching https://api.nytimes.com/svc/archive/v1/2016/12.json?api-key=yHXr5g15kLco2gm87B9GKpQ1USXUQZPO
# INFO:NYT downloader:Extracted 4967 urls
# INFO:NYT downloader:Saving urls to C:/Users/naomi/OneDrive/COMP80004_PhDResearch/RESEARCH/DATA/CORPORA/MEDIA/NYT/output\urls_2016.txt
# INFO:NYT downloader:Fetching https://api.nytimes.com/svc/archive/v1/2017/1.json?api-key=yHXr5g15kLco2gm87B9GKpQ1USXUQZPO
# INFO:NYT downloader:Extracted 5129 urls
# INFO:NYT downloader:Fetching https://api.nytimes.com/svc/archive/v1/2017/2.json?api-key=yHXr5g15kLco2gm87B9GKpQ1USXUQZPO
# INFO:NYT downloader:Extracted 4935 urls
# INFO:NYT downloader:Fetching https://api.nytimes.com/svc/archive/v1/2017/3.json?api-key=yHXr5g15kLco2gm87B9GKpQ1USXUQZPO
# INFO:NYT downloader:Extracted 5546 urls
# INFO:NYT downloader:Fetching https://api.nytimes.com/svc/archive/v1/2017/4.json?api-key=yHXr5g15kLco2gm87B9GKpQ1USXUQZPO
# INFO:NYT downloader:Extracted 4878 urls
# INFO:NYT downloader:Fetching https://api.nytimes.com/svc/archive/v1/2017/5.json?api-key=yHXr5g15kLco2gm87B9GKpQ1USXUQZPO
# INFO:NYT downloader:Extracted 5384 urls
# INFO:NYT downloader:Fetching https://api.nytimes.com/svc/archive/v1/2017/6.json?api-key=yHXr5g15kLco2gm87B9GKpQ1USXUQZPO
# INFO:NYT downloader:Extracted 5300 urls
# INFO:NYT downloader:Fetching https://api.nytimes.com/svc/archive/v1/2017/7.json?api-key=yHXr5g15kLco2gm87B9GKpQ1USXUQZPO
# INFO:NYT downloader:Extracted 4757 urls
# INFO:NYT downloader:Fetching https://api.nytimes.com/svc/archive/v1/2017/8.json?api-key=yHXr5g15kLco2gm87B9GKpQ1USXUQZPO
# INFO:NYT downloader:Extracted 4854 urls
# INFO:NYT downloader:Fetching https://api.nytimes.com/svc/archive/v1/2017/9.json?api-key=yHXr5g15kLco2gm87B9GKpQ1USXUQZPO
# INFO:NYT downloader:Extracted 5033 urls
# INFO:NYT downloader:Fetching https://api.nytimes.com/svc/archive/v1/2017/10.json?api-key=yHXr5g15kLco2gm87B9GKpQ1USXUQZPO
# INFO:NYT downloader:Extracted 5214 urls
# INFO:NYT downloader:Fetching https://api.nytimes.com/svc/archive/v1/2017/11.json?api-key=yHXr5g15kLco2gm87B9GKpQ1USXUQZPO
# INFO:NYT downloader:Extracted 4834 urls
# INFO:NYT downloader:Fetching https://api.nytimes.com/svc/archive/v1/2017/12.json?api-key=yHXr5g15kLco2gm87B9GKpQ1USXUQZPO
# INFO:NYT downloader:Extracted 4560 urls
# INFO:NYT downloader:Saving urls to C:/Users/naomi/OneDrive/COMP80004_PhDResearch/RESEARCH/DATA/CORPORA/MEDIA/NYT/output\urls_2017.txt
# INFO:NYT downloader:Fetching https://api.nytimes.com/svc/archive/v1/2018/1.json?api-key=yHXr5g15kLco2gm87B9GKpQ1USXUQZPO
# INFO:NYT downloader:Extracted 4757 urls
# INFO:NYT downloader:Fetching https://api.nytimes.com/svc/archive/v1/2018/2.json?api-key=yHXr5g15kLco2gm87B9GKpQ1USXUQZPO
# INFO:NYT downloader:Extracted 4573 urls
# INFO:NYT downloader:Fetching https://api.nytimes.com/svc/archive/v1/2018/3.json?api-key=yHXr5g15kLco2gm87B9GKpQ1USXUQZPO
# INFO:NYT downloader:Extracted 5034 urls
# INFO:NYT downloader:Fetching https://api.nytimes.com/svc/archive/v1/2018/4.json?api-key=yHXr5g15kLco2gm87B9GKpQ1USXUQZPO
# INFO:NYT downloader:Extracted 4655 urls
# INFO:NYT downloader:Fetching https://api.nytimes.com/svc/archive/v1/2018/5.json?api-key=yHXr5g15kLco2gm87B9GKpQ1USXUQZPO
# INFO:NYT downloader:Extracted 5127 urls
# INFO:NYT downloader:Fetching https://api.nytimes.com/svc/archive/v1/2018/6.json?api-key=yHXr5g15kLco2gm87B9GKpQ1USXUQZPO
# INFO:NYT downloader:Extracted 4988 urls
# INFO:NYT downloader:Fetching https://api.nytimes.com/svc/archive/v1/2018/7.json?api-key=yHXr5g15kLco2gm87B9GKpQ1USXUQZPO
# INFO:NYT downloader:Extracted 4444 urls
# INFO:NYT downloader:Fetching https://api.nytimes.com/svc/archive/v1/2018/8.json?api-key=yHXr5g15kLco2gm87B9GKpQ1USXUQZPO
# INFO:NYT downloader:Extracted 6381 urls
# INFO:NYT downloader:Fetching https://api.nytimes.com/svc/archive/v1/2018/9.json?api-key=yHXr5g15kLco2gm87B9GKpQ1USXUQZPO
# INFO:NYT downloader:Extracted 4722 urls
# INFO:NYT downloader:Fetching https://api.nytimes.com/svc/archive/v1/2018/10.json?api-key=yHXr5g15kLco2gm87B9GKpQ1USXUQZPO
# INFO:NYT downloader:Extracted 5146 urls
# INFO:NYT downloader:Fetching https://api.nytimes.com/svc/archive/v1/2018/11.json?api-key=yHXr5g15kLco2gm87B9GKpQ1USXUQZPO
# INFO:NYT downloader:Extracted 4829 urls
# INFO:NYT downloader:Fetching https://api.nytimes.com/svc/archive/v1/2018/12.json?api-key=yHXr5g15kLco2gm87B9GKpQ1USXUQZPO
# INFO:NYT downloader:Extracted 4193 urls
# INFO:NYT downloader:Saving urls to C:/Users/naomi/OneDrive/COMP80004_PhDResearch/RESEARCH/DATA/CORPORA/MEDIA/NYT/output\urls_2018.txt
# INFO:NYT downloader:Fetching https://api.nytimes.com/svc/archive/v1/2019/1.json?api-key=yHXr5g15kLco2gm87B9GKpQ1USXUQZPO
# INFO:NYT downloader:Extracted 4482 urls
# INFO:NYT downloader:Fetching https://api.nytimes.com/svc/archive/v1/2019/2.json?api-key=yHXr5g15kLco2gm87B9GKpQ1USXUQZPO
# INFO:NYT downloader:Extracted 4122 urls
# INFO:NYT downloader:Fetching https://api.nytimes.com/svc/archive/v1/2019/3.json?api-key=yHXr5g15kLco2gm87B9GKpQ1USXUQZPO
# INFO:NYT downloader:Extracted 4690 urls
# INFO:NYT downloader:Fetching https://api.nytimes.com/svc/archive/v1/2019/4.json?api-key=yHXr5g15kLco2gm87B9GKpQ1USXUQZPO
# INFO:NYT downloader:Extracted 4523 urls
# INFO:NYT downloader:Fetching https://api.nytimes.com/svc/archive/v1/2019/5.json?api-key=yHXr5g15kLco2gm87B9GKpQ1USXUQZPO
# INFO:NYT downloader:Extracted 4737 urls
# INFO:NYT downloader:Fetching https://api.nytimes.com/svc/archive/v1/2019/6.json?api-key=yHXr5g15kLco2gm87B9GKpQ1USXUQZPO
# INFO:NYT downloader:Extracted 4496 urls
# INFO:NYT downloader:Fetching https://api.nytimes.com/svc/archive/v1/2019/7.json?api-key=yHXr5g15kLco2gm87B9GKpQ1USXUQZPO
# INFO:NYT downloader:Extracted 4287 urls
# INFO:NYT downloader:Fetching https://api.nytimes.com/svc/archive/v1/2019/8.json?api-key=yHXr5g15kLco2gm87B9GKpQ1USXUQZPO
# INFO:NYT downloader:Extracted 4109 urls
# INFO:NYT downloader:Fetching https://api.nytimes.com/svc/archive/v1/2019/9.json?api-key=yHXr5g15kLco2gm87B9GKpQ1USXUQZPO
# INFO:NYT downloader:Extracted 4418 urls
# INFO:NYT downloader:Fetching https://api.nytimes.com/svc/archive/v1/2019/10.json?api-key=yHXr5g15kLco2gm87B9GKpQ1USXUQZPO
# INFO:NYT downloader:Extracted 4989 urls
# INFO:NYT downloader:Fetching https://api.nytimes.com/svc/archive/v1/2019/11.json?api-key=yHXr5g15kLco2gm87B9GKpQ1USXUQZPO
# INFO:NYT downloader:Extracted 4420 urls
# INFO:NYT downloader:Fetching https://api.nytimes.com/svc/archive/v1/2019/12.json?api-key=yHXr5g15kLco2gm87B9GKpQ1USXUQZPO
# INFO:NYT downloader:Extracted 3985 urls
# INFO:NYT downloader:Saving urls to C:/Users/naomi/OneDrive/COMP80004_PhDResearch/RESEARCH/DATA/CORPORA/MEDIA/NYT/output\urls_2019.txt
# INFO:NYT downloader:Fetching https://api.nytimes.com/svc/archive/v1/2020/1.json?api-key=yHXr5g15kLco2gm87B9GKpQ1USXUQZPO
# INFO:NYT downloader:Extracted 4480 urls
# INFO:NYT downloader:Fetching https://api.nytimes.com/svc/archive/v1/2020/2.json?api-key=yHXr5g15kLco2gm87B9GKpQ1USXUQZPO
# INFO:NYT downloader:Extracted 4240 urls
# INFO:NYT downloader:Fetching https://api.nytimes.com/svc/archive/v1/2020/3.json?api-key=yHXr5g15kLco2gm87B9GKpQ1USXUQZPO
# INFO:NYT downloader:Extracted 4883 urls
# INFO:NYT downloader:Fetching https://api.nytimes.com/svc/archive/v1/2020/4.json?api-key=yHXr5g15kLco2gm87B9GKpQ1USXUQZPO
# INFO:NYT downloader:Extracted 5019 urls
# INFO:NYT downloader:Fetching https://api.nytimes.com/svc/archive/v1/2020/5.json?api-key=yHXr5g15kLco2gm87B9GKpQ1USXUQZPO
# INFO:NYT downloader:Extracted 4347 urls
# INFO:NYT downloader:Fetching https://api.nytimes.com/svc/archive/v1/2020/6.json?api-key=yHXr5g15kLco2gm87B9GKpQ1USXUQZPO
# INFO:NYT downloader:Extracted 4492 urls
# INFO:NYT downloader:Fetching https://api.nytimes.com/svc/archive/v1/2020/7.json?api-key=yHXr5g15kLco2gm87B9GKpQ1USXUQZPO
# INFO:NYT downloader:Extracted 4459 urls
# INFO:NYT downloader:Fetching https://api.nytimes.com/svc/archive/v1/2020/8.json?api-key=yHXr5g15kLco2gm87B9GKpQ1USXUQZPO
# INFO:NYT downloader:Extracted 4439 urls
# INFO:NYT downloader:Fetching https://api.nytimes.com/svc/archive/v1/2020/9.json?api-key=yHXr5g15kLco2gm87B9GKpQ1USXUQZPO
# INFO:NYT downloader:Extracted 4609 urls
# INFO:NYT downloader:Fetching https://api.nytimes.com/svc/archive/v1/2020/10.json?api-key=yHXr5g15kLco2gm87B9GKpQ1USXUQZPO
# INFO:NYT downloader:Extracted 5257 urls
# INFO:NYT downloader:Fetching https://api.nytimes.com/svc/archive/v1/2020/11.json?api-key=yHXr5g15kLco2gm87B9GKpQ1USXUQZPO
# INFO:NYT downloader:Extracted 5114 urls
# INFO:NYT downloader:Fetching https://api.nytimes.com/svc/archive/v1/2020/12.json?api-key=yHXr5g15kLco2gm87B9GKpQ1USXUQZPO
# INFO:NYT downloader:Extracted 4154 urls
# INFO:NYT downloader:Saving urls to C:/Users/naomi/OneDrive/COMP80004_PhDResearch/RESEARCH/DATA/CORPORA/MEDIA/NYT/output\urls_2020.txt
# INFO:NYT downloader:Fetching https://api.nytimes.com/svc/archive/v1/2021/1.json?api-key=yHXr5g15kLco2gm87B9GKpQ1USXUQZPO
# INFO:NYT downloader:Extracted 7001 urls
# INFO:NYT downloader:Fetching https://api.nytimes.com/svc/archive/v1/2021/2.json?api-key=yHXr5g15kLco2gm87B9GKpQ1USXUQZPO
# INFO:NYT downloader:Extracted 4260 urls
# INFO:NYT downloader:Fetching https://api.nytimes.com/svc/archive/v1/2021/3.json?api-key=yHXr5g15kLco2gm87B9GKpQ1USXUQZPO
# INFO:NYT downloader:Extracted 4786 urls
# INFO:NYT downloader:Fetching https://api.nytimes.com/svc/archive/v1/2021/4.json?api-key=yHXr5g15kLco2gm87B9GKpQ1USXUQZPO
# INFO:NYT downloader:Extracted 4592 urls
# INFO:NYT downloader:Fetching https://api.nytimes.com/svc/archive/v1/2021/5.json?api-key=yHXr5g15kLco2gm87B9GKpQ1USXUQZPO
# INFO:NYT downloader:Extracted 4265 urls
# INFO:NYT downloader:Fetching https://api.nytimes.com/svc/archive/v1/2021/6.json?api-key=yHXr5g15kLco2gm87B9GKpQ1USXUQZPO
# INFO:NYT downloader:Extracted 4260 urls
# INFO:NYT downloader:Fetching https://api.nytimes.com/svc/archive/v1/2021/7.json?api-key=yHXr5g15kLco2gm87B9GKpQ1USXUQZPO
# INFO:NYT downloader:Extracted 4467 urls
# INFO:NYT downloader:Fetching https://api.nytimes.com/svc/archive/v1/2021/8.json?api-key=yHXr5g15kLco2gm87B9GKpQ1USXUQZPO
# INFO:NYT downloader:Extracted 4223 urls
# INFO:NYT downloader:Fetching https://api.nytimes.com/svc/archive/v1/2021/9.json?api-key=yHXr5g15kLco2gm87B9GKpQ1USXUQZPO
# INFO:NYT downloader:Extracted 4482 urls
# INFO:NYT downloader:Fetching https://api.nytimes.com/svc/archive/v1/2021/10.json?api-key=yHXr5g15kLco2gm87B9GKpQ1USXUQZPO
# INFO:NYT downloader:Extracted 4254 urls
# INFO:NYT downloader:Fetching https://api.nytimes.com/svc/archive/v1/2021/11.json?api-key=yHXr5g15kLco2gm87B9GKpQ1USXUQZPO
# INFO:NYT downloader:Extracted 4006 urls
# INFO:NYT downloader:Fetching https://api.nytimes.com/svc/archive/v1/2021/12.json?api-key=yHXr5g15kLco2gm87B9GKpQ1USXUQZPO
# INFO:NYT downloader:Extracted 3933 urls
# INFO:NYT downloader:Saving urls to C:/Users/naomi/OneDrive/COMP80004_PhDResearch/RESEARCH/DATA/CORPORA/MEDIA/NYT/output\urls_2021.txt
# INFO:NYT downloader:Fetching https://api.nytimes.com/svc/archive/v1/2022/1.json?api-key=yHXr5g15kLco2gm87B9GKpQ1USXUQZPO
# INFO:NYT downloader:Extracted 3799 urls
# INFO:NYT downloader:Fetching https://api.nytimes.com/svc/archive/v1/2022/2.json?api-key=yHXr5g15kLco2gm87B9GKpQ1USXUQZPO
# INFO:NYT downloader:Extracted 4059 urls
# INFO:NYT downloader:Fetching https://api.nytimes.com/svc/archive/v1/2022/3.json?api-key=yHXr5g15kLco2gm87B9GKpQ1USXUQZPO
# INFO:NYT downloader:Extracted 4310 urls
# INFO:NYT downloader:Fetching https://api.nytimes.com/svc/archive/v1/2022/4.json?api-key=yHXr5g15kLco2gm87B9GKpQ1USXUQZPO
# INFO:NYT downloader:Extracted 3934 urls
# INFO:NYT downloader:Fetching https://api.nytimes.com/svc/archive/v1/2022/5.json?api-key=yHXr5g15kLco2gm87B9GKpQ1USXUQZPO
# INFO:NYT downloader:Extracted 4179 urls
# INFO:NYT downloader:Fetching https://api.nytimes.com/svc/archive/v1/2022/6.json?api-key=yHXr5g15kLco2gm87B9GKpQ1USXUQZPO
# INFO:NYT downloader:Extracted 4374 urls
# INFO:NYT downloader:Fetching https://api.nytimes.com/svc/archive/v1/2022/7.json?api-key=yHXr5g15kLco2gm87B9GKpQ1USXUQZPO
# INFO:NYT downloader:Extracted 3835 urls
# INFO:NYT downloader:Fetching https://api.nytimes.com/svc/archive/v1/2022/8.json?api-key=yHXr5g15kLco2gm87B9GKpQ1USXUQZPO
# INFO:NYT downloader:Extracted 3983 urls
# INFO:NYT downloader:Fetching https://api.nytimes.com/svc/archive/v1/2022/9.json?api-key=yHXr5g15kLco2gm87B9GKpQ1USXUQZPO
# INFO:NYT downloader:Extracted 4087 urls
# INFO:NYT downloader:Fetching https://api.nytimes.com/svc/archive/v1/2022/10.json?api-key=yHXr5g15kLco2gm87B9GKpQ1USXUQZPO
# INFO:NYT downloader:Extracted 3857 urls
# INFO:NYT downloader:Fetching https://api.nytimes.com/svc/archive/v1/2022/11.json?api-key=yHXr5g15kLco2gm87B9GKpQ1USXUQZPO
# INFO:NYT downloader:Extracted 4742 urls
# INFO:NYT downloader:Fetching https://api.nytimes.com/svc/archive/v1/2022/12.json?api-key=yHXr5g15kLco2gm87B9GKpQ1USXUQZPO
# INFO:NYT downloader:Extracted 3548 urls
# INFO:NYT downloader:Saving urls to C:/Users/naomi/OneDrive/COMP80004_PhDResearch/RESEARCH/DATA/CORPORA/MEDIA/NYT/output\urls_2022.txt
# INFO:NYT downloader:Fetching https://api.nytimes.com/svc/archive/v1/2023/1.json?api-key=yHXr5g15kLco2gm87B9GKpQ1USXUQZPO
# INFO:NYT downloader:Extracted 3423 urls
# INFO:NYT downloader:Fetching https://api.nytimes.com/svc/archive/v1/2023/2.json?api-key=yHXr5g15kLco2gm87B9GKpQ1USXUQZPO
# INFO:NYT downloader:Extracted 3260 urls
# INFO:NYT downloader:Fetching https://api.nytimes.com/svc/archive/v1/2023/3.json?api-key=yHXr5g15kLco2gm87B9GKpQ1USXUQZPO
# INFO:NYT downloader:Extracted 5769 urls
# INFO:NYT downloader:Fetching https://api.nytimes.com/svc/archive/v1/2023/4.json?api-key=yHXr5g15kLco2gm87B9GKpQ1USXUQZPO
# INFO:NYT downloader:Extracted 3718 urls
# INFO:NYT downloader:Fetching https://api.nytimes.com/svc/archive/v1/2023/5.json?api-key=yHXr5g15kLco2gm87B9GKpQ1USXUQZPO
# INFO:NYT downloader:Extracted 3881 urls
# INFO:NYT downloader:Fetching https://api.nytimes.com/svc/archive/v1/2023/6.json?api-key=yHXr5g15kLco2gm87B9GKpQ1USXUQZPO
# INFO:NYT downloader:Extracted 3788 urls
# INFO:NYT downloader:Fetching https://api.nytimes.com/svc/archive/v1/2023/7.json?api-key=yHXr5g15kLco2gm87B9GKpQ1USXUQZPO
# INFO:NYT downloader:Extracted 3548 urls
# INFO:NYT downloader:Fetching https://api.nytimes.com/svc/archive/v1/2023/8.json?api-key=yHXr5g15kLco2gm87B9GKpQ1USXUQZPO
# INFO:NYT downloader:Extracted 3668 urls
# INFO:NYT downloader:Fetching https://api.nytimes.com/svc/archive/v1/2023/9.json?api-key=yHXr5g15kLco2gm87B9GKpQ1USXUQZPO
# INFO:NYT downloader:Extracted 3823 urls
# INFO:NYT downloader:Fetching https://api.nytimes.com/svc/archive/v1/2023/10.json?api-key=yHXr5g15kLco2gm87B9GKpQ1USXUQZPO
# INFO:NYT downloader:Extracted 3906 urls
# INFO:NYT downloader:Fetching https://api.nytimes.com/svc/archive/v1/2023/11.json?api-key=yHXr5g15kLco2gm87B9GKpQ1USXUQZPO
# INFO:NYT downloader:Extracted 3734 urls
# INFO:NYT downloader:Fetching https://api.nytimes.com/svc/archive/v1/2023/12.json?api-key=yHXr5g15kLco2gm87B9GKpQ1USXUQZPO
# INFO:NYT downloader:Extracted 3525 urls
# INFO:NYT downloader:Saving urls to C:/Users/naomi/OneDrive/COMP80004_PhDResearch/RESEARCH/DATA/CORPORA/MEDIA/NYT/output\urls_2023.txt
